# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import os.path
import ast

# %%
matplotlib.rcParams['figure.figsize'] = (12, 10)

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Data Exploration

# %%
data_file = 'data.csv'

if not os.path.exists(data_file):
    print('Cannot find data')

# %%
df = pd.read_csv('data.csv', sep=',', header=0)

# %%
df.head()
# Out:
#          source_file  lineno  ast_depth  num_test_cover  num_executed  \
# 0  src/calculator.py       3          3               2             4
# 1  src/calculator.py       3          4               2             4
# 2  src/calculator.py       7          5               1             1
# 3  src/calculator.py       7          5               1             1
# 4  src/calculator.py       7          5               1             1
#
#    num_assert_tm  num_assert_tc mutant_operator_type  function_max_depth  \
# 0              3             20                  AOD                  10
# 1              3             20                  AOR                  10
# 2              1             20                  AOR                   7
# 3              1             20                  AOR                   7
# 4              1             20                  AOR                   7
#
#    function_avg_depth  class_max_depth  lineno_loc           loc_list  \
# 0                 8.5               10           5  ['8:14', '16:17']
# 1                 8.5               10           5  ['8:14', '16:17']
# 2                 7.0               10           0          ['20:21']
# 3                 7.0               10           0          ['20:21']
# 4                 7.0               10           0          ['20:21']
#
#    mutation_number    status
# 0                1    killed
# 1                2    killed
# 2                3    killed
# 3                4    killed
# 4                5  survived

# %%
df
# Out:
#           source_file  lineno  ast_depth  num_test_cover  num_executed  \
# 0   src/calculator.py       3          3               2             4
# 1   src/calculator.py       3          4               2             4
# 2   src/calculator.py       7          5               1             1
# 3   src/calculator.py       7          5               1             1
# 4   src/calculator.py       7          5               1             1
# 5   src/calculator.py       7          4               1             1
# 6   src/calculator.py       7          4               1             1
# 7   src/calculator.py       7          4               1             1
# 8   src/calculator.py      11          3               1             1
# 9   src/calculator.py      18          4               1             1
# 10  src/calculator.py      23          3               1             1
# 11  src/calculator.py      17          3               1             4
# 12  src/calculator.py      23          2               1             1
# 13  src/calculator.py      29          2               1             1
# 14  src/calculator.py      90          2               1             1
# 15  src/calculator.py      92          2               0             0
# 16  src/calculator.py     106          2               1             1
# 17  src/calculator.py       7          4               1             1
# 18  src/calculator.py      16          3               1             4
# 19  src/calculator.py      16          3               1             4
# 20  src/calculator.py      17          6               1             4
# 21  src/calculator.py      17          6               1             4
# 22  src/calculator.py      35          3               1             1
# 23  src/calculator.py      36          3               1             1
# 24  src/calculator.py      36          3               1             1
# 25  src/calculator.py      57          6               0             0
# 26  src/calculator.py      57          6               0             0
# 27  src/calculator.py      61          3               0             1
# 28  src/calculator.py      65          3               0             1
# 29  src/calculator.py      86          4               1             1
# 30  src/calculator.py      41          2               0             1
# 31  src/calculator.py      49          3               0             0
# 32  src/calculator.py      56          3               0             0
# 33  src/calculator.py      84          2               0             1
# 34  src/calculator.py      90          5               1             1
# 35  src/calculator.py      92          5               0             0
# 36  src/calculator.py      97          3               1             1
# 37  src/calculator.py     101          4               1             1
# 38  src/calculator.py     102          4               1             1
# 39  src/calculator.py      17          6               1             4
# 40  src/calculator.py     106          5               1             1
# 41  src/calculator.py     106          5               1             1
# 42  src/calculator.py      84          2               0             1
# 43  src/calculator.py     116          2               0             1
#
#     num_assert_tm  num_assert_tc mutant_operator_type  function_max_depth  \
# 0               3             20                  AOD                  10
# 1               3             20                  AOR                  10
# 2               1             20                  AOR                   7
# 3               1             20                  AOR                   7
# 4               1             20                  AOR                   7
# 5               1             20                  AOR                   7
# 6               1             20                  AOR                   7
# 7               1             20                  AOR                   7
# 8               1             20                  ASR                   7
# 9               1             20                  BCR                   7
# 10              1             20                  COD                   7
# 11              1             20                  COI                   7
# 12              1             20                  COI                   7
# 13              1             20                  COI                   7
# 14              1             20                  COI                   7
# 15              0              0                  COI                   0
# 16              1             20                  COI                   7
# 17              1             20                  CRP                   7
# 18              1             20                  CRP                   7
# 19              1             20                  CRP                   7
# 20              1             20                  CRP                   7
# 21              1             20                  CRP                   7
# 22              1             20                  CRP                   7
# 23              1             20                  CRP                   7
# 24              1             20                  CRP                   7
# 25              0              0                  CRP                   0
# 26              0              0                  CRP                   0
# 27              0              0                  CRP                   0
# 28              0              0                  CRP                   0
# 29              1             20                  CRP                   6
# 30              0              0                  DDL                   0
# 31              0              0                  EHD                   0
# 32              0              0                  EXS                   0
# 33              0              0                  IOP                   0
# 34              1             20                  LCR                   7
# 35              0              0                  LCR                   0
# 36              1             20                  LOD                   7
# 37              1             20                  LOR                   7
# 38              1             20                  LOR                   7
# 39              1             20                  ROR                   7
# 40              1             20                  ROR                   7
# 41              1             20                  ROR                   7
# 42              0              0                  SCD                   0
# 43              0              0                  SCD                   0
#
#     function_avg_depth  class_max_depth  lineno_loc           loc_list  \
# 0                  8.5               10           5  ['8:14', '16:17']
# 1                  8.5               10           5  ['8:14', '16:17']
# 2                  7.0               10           0          ['20:21']
# 3                  7.0               10           0          ['20:21']
# 4                  7.0               10           0          ['20:21']
# 5                  7.0               10           0          ['20:21']
# 6                  7.0               10           0          ['20:21']
# 7                  7.0               10           0          ['20:21']
# 8                  7.0               10           0          ['23:24']
# 9                  7.0               10           0          ['26:27']
# 10                 7.0               10           0          ['29:30']
# 11                 7.0               10           0          ['26:27']
# 12                 7.0               10           0          ['29:30']
# 13                 7.0               10           0          ['32:33']
# 14                 7.0               10           0          ['60:61']
# 15                 0.0                0           0                 []
# 16                 7.0               10           0          ['69:70']
# 17                 7.0               10           0          ['20:21']
# 18                 7.0               10           0          ['26:27']
# 19                 7.0               10           0          ['26:27']
# 20                 7.0               10           0          ['26:27']
# 21                 7.0               10           0          ['26:27']
# 22                 7.0               10           0          ['35:36']
# 23                 7.0               10           0          ['35:36']
# 24                 7.0               10           0          ['35:36']
# 25                 0.0                0           0                 []
# 26                 0.0                0           0                 []
# 27                 0.0                0           0                 []
# 28                 0.0                0           0                 []
# 29                 6.0               10           1          ['56:58']
# 30                 0.0                0           0                 []
# 31                 0.0                0           0                 []
# 32                 0.0                0           0                 []
# 33                 0.0                0           0                 []
# 34                 7.0               10           0          ['60:61']
# 35                 0.0                0           0                 []
# 36                 7.0               10           0          ['63:64']
# 37                 7.0               10           0          ['66:67']
# 38                 7.0               10           0          ['66:67']
# 39                 7.0               10           0          ['26:27']
# 40                 7.0               10           0          ['69:70']
# 41                 7.0               10           0          ['69:70']
# 42                 0.0                0           0                 []
# 43                 0.0                0           0                 []
#
#     mutation_number    status
# 0                 1    killed
# 1                 2    killed
# 2                 3    killed
# 3                 4    killed
# 4                 5  survived
# 5                 6    killed
# 6                 7    killed
# 7                 8    killed
# 8                 9    killed
# 9                10    killed
# 10               11    killed
# 11               12    killed
# 12               13    killed
# 13               14    killed
# 14               15  survived
# 15               16  survived
# 16               17  survived
# 17               18    killed
# 18               19    killed
# 19               20    killed
# 20               21    killed
# 21               22    killed
# 22               23    killed
# 23               24    killed
# 24               25    killed
# 25               26  survived
# 26               27  survived
# 27               28  survived
# 28               29    killed
# 29               30  survived
# 30               31  survived
# 31               32  survived
# 32               33  survived
# 33               34    killed
# 34               35  survived
# 35               36  survived
# 36               37  survived
# 37               38  survived
# 38               39  survived
# 39               40  survived
# 40               41  survived
# 41               42    killed
# 42               43  survived
# 43               44  survived

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().values.any()
# Out:
# False

# %%
X = df.drop(labels=['status','mutation_number', 'loc_list'], axis=1)
y = df[['status']]
use_for_semantic_analysis = df[['loc_list']]

# %%
X[0:5]
# Out:
#          source_file  lineno  ast_depth  num_test_cover  num_executed  \
# 0  src/calculator.py       3          3               2             4
# 1  src/calculator.py       3          4               2             4
# 2  src/calculator.py       7          5               1             1
# 3  src/calculator.py       7          5               1             1
# 4  src/calculator.py       7          5               1             1
#
#    num_assert_tm  num_assert_tc mutant_operator_type  function_max_depth  \
# 0              3             20                  AOD                  10
# 1              3             20                  AOR                  10
# 2              1             20                  AOR                   7
# 3              1             20                  AOR                   7
# 4              1             20                  AOR                   7
#
#    function_avg_depth  class_max_depth  lineno_loc
# 0                 8.5               10           5
# 1                 8.5               10           5
# 2                 7.0               10           0
# 3                 7.0               10           0
# 4                 7.0               10           0

# %%
y[0:5]
# Out:
#      status
# 0    killed
# 1    killed
# 2    killed
# 3    killed
# 4  survived
